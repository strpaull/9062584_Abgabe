# %% [markdown]
# # Deep Classroom
# Contact and Copyright: Mark.schutera@mailbox.com
#
#
#
# I am happy to have you. In the following, you will interactively experience and explore the world of artificial intelligence, machine learning, or, even more specifically, deep learning. You will get to know...
# - the general design of a deep learning pipeline
# - the basic principles behind deep learning
# - the fundamental neural network architecture
# - the process of training a neural network
# - the deployment of your trained neural network
# - the validation of your model
#
# After this course, you will know the basics of...
# - the look and feel of the programming language python
# - the deep learning packages tensorflow and Keras
# - the intuitions and approaches within deep learning
# - much more
#
# This course will enable you to set up your own deep learning projects, train your own models on your own data. You will be well on your way to become a deep learning engineer, machine learning researcher, deploying the power of deep learning to generate progress, make the world a better place and solve the pressing problems of today and tomorrow. This sounds exciting - it is! And you are precisely in the right place - Buckle Up!
#
# <img src="graphics/welcome.svg" width="500"><br>

# %% [markdown]
# There will be emojis along the way. These are for virtual lectures with this notebook. They help your lecturer stay aware of how you and others progress. Once you reach a smiley, please post it within the chat function of your virtual meeting tool.
#
# 😍 Smiling Face with Heart-Eyes

# %% [markdown]
# ## Getting comfortable in the driver's seat!
#
# The interface you are seeing in front of you is called jupyter notebook, an excellent interactive way to present and communicate code. Think of it as your cockpit. The nice thing is that in the back, we already got your engine preheated and ready to rumble, waiting for you to kick the pedal to the metal. Thanks to [binder](https://mybinder.org/) you can execute the code, on your machine using binders compute power.
#
# In principle, this notebook is structured in cells, which get highlighted once you select them. There are two types of cells. The markdown cells (such as this one) are for everything that is not code. Here you will find explanations, descriptions, figures, and many more. The other type of cell is for code. Here you can interactively change code and run it within your browser.
#
# Navigate to the next cell by using the down-arrow or click on the next cell...

# %%
# Great job. This is an interactive python cell with an easy print function. Feel free to change and play around with it.

print('Ready Player!')

# A hashtag is used to comment on stuff that is not executed as code. This is useful if you want to add an explanation or further relevant information to your code.
# Run a cell by clicking the Run button above, or by Ctrl + Enter (on your german keyboard, this is Strg + Enter) 

# Notice the output below the cell.
# Out:
# Ready Player!

# %%
# We will use this cell to import all the packages you will need in the following - think of it as turning on all your systems
# in your cockpit
    
# This makes sure that if you change code in your external scripts, they will be updated


import checker
import generator

from IPython.display import display, clear_output
import numpy as np
#from sklearn.decomposition import PCA
import time
import math
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

import importlib
importlib.reload(checker)
importlib.reload(generator)

# now go ahead and Run the cell. This might take a while...
# while the cell is running, you will see ln[*] next to it. Once it finished, you will see the number of execution
# In case you want to interrupt the run of a cell, press Ctrl + C (on your german keyboard, this is Strg + C)
# Out:
# <module 'generator' from 'C:\\Users\\pauls\\Desktop\\Neuronale Netze\\generator.py'>

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.26.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: C:\Users\pauls\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %% [markdown]
# ##### Hint:
# Below code cells you sometimes find, what we call hints. So in case you get stuck, or are in search of additional information this is the place for additional elaboration on the topic or links. <br>
# - [print()](https://docs.python.org/3/library/functions.html#print) <br>
# - [import](https://docs.python.org/3/reference/simple_stmts.html#import)
#
# ##### Side Quest:
# Another feature is the side quests. These are things you could try, think about, and tease your brain with. They are not necessary for you to learn the fundamentals. They are nevertheless, valuable for your holistic understanding of the subject. Also, they are fun.

# %% [markdown]
# ### Making sure you are still on track
#
# Next, welcome to the world of what we call sanity checks.
# Every now and then, you will find sanity checks below your interactive code cells.
# These are to make sure that your code does what it should (this is usually called a [unit test](https://en.wikipedia.org/wiki/Unit_testing)).
# Once your code passed the unit test, it is safe for you to go ahead with the notebook.
# So do not touch the code within a sanity check cell. Instead, just run it and fix your code in the respective cell.

# %%
# Write a function that adds a to b and returns c

def add(a,b):
    c = a + b
    # the code goes here flag has to be removed and indicates that you need to pick your brain and write some code.
    
    return c

# %% [markdown]
# ##### Hint:
# An addition in python can be done by simply writing a '+' sign connecting the two input arguments. An alternative is to use a dedicated function that takes an array of values. <br>
# - [sum([a, b])](https://docs.python.org/3/library/functions.html#sum) <br>

# %%
# After writing the add function in the cell above, go ahead and run this cell.

'''
 ____   __   __ _  __  ____  _  _     ___  _  _  ____  ___  __ _ 
/ ___) / _\ (  ( \(  )(_  _)( \/ )   / __)/ )( \(  __)/ __)(  / )
\___ \/    \/    / )(   )(   )  /   ( (__ ) __ ( ) _)( (__  )  ( 
(____/\_/\_/\_)__)(__) (__) (__/     \___)\_)(_/(____)\___)(__\_)

Do not touch, just run!
'''
checker.test_add(add)


# If your code is working correctly, you will be prompted with the message "Everything passed, 
# you are ready to go."
# This means you can continue with the next cell

# If there is a bug in your code, you will be prompted with an AssertionError, 
# outlining how your code failed.

# Go ahead, break your code and see what's happening to get a feeling for the sanity checks. 
# Then feel free to move on.
# Out:
# Everything passed, you are ready to go.

# %% [markdown]
# Now that you know how to drive this thing, you are ready for some real action.

# %% [markdown]
# ## Talking about brains
#
# Your brain is the most astonishing multi-purpose computer around. And neuroscientists and engineers alike have been trying to understand the mechanics of brains, to apply their findings to other fields, such as computer science. This is how the idea of artificial neural networks came into being. <br>
#
# Your brain comprises approximately 80 billion neurons, or brain cells, which are heavily interconnected with what are called synapses. Neurons communicate with each other by sending electrical impulses through these synapses. If a neuron receives enough of these messages, the neuron itself sends an impulse to the neurons it is connected with. In this way, the brain can process complex data, extract features, and recognize a pattern. <br>
#
# And this is not yet, the most exciting ability of the brain. Your brain is further able to learn, adjusting to newly perceived data, patterns, and behavior. This happens by either strengthening or weakening the connection or synapses between neurons, influencing their interplay. <br>

# %% [markdown]
# 🙃 Upside-Down Face

# %%
# pip install --upgrade tensorflow==2.7.0

# %% [markdown]
# So we get to concentrate on the training hyperparameters and process and the neural network architecture design. Not to forget adding layers - juhuuu!
#
# <br>
#
# In the following, you will be introduced to...
# - .. [tensorflow](https://www.tensorflow.org/)
# - .. [keras](https://keras.io/)
#
# While you will clamber on the "Hello World!" of deep learning, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset.

# %%
# There is this joke that once you have added this import line to your code, 
# you are allowed to sell your product telling everyone that you are using AI. Life is easy, sometimes.

import tensorflow as tf        
print('Tensorflow version:', tf.__version__, '(Expected 2.7.0)')



# Keras is a model-level library, meaning that it is built upon tensorflow (using it as a backend) - allowing for
# high-level building blocks. Making it even easier to design neural networks.
# We will access it as tf.keras

# The tf and k abbreviations are best practice (same for numpy np and pandas pd), 
# since you do not want to type T E N S O R F L O W all over your code.
# They are prevalent all over the industry and academia in a way that you'll risk a fight if you import them differently.
# Out:
# Tensorflow version: 2.14.0 (Expected 2.7.0)

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (2.14.0)
# Requirement already satisfied: tensorflow-intel==2.14.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.26.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.24.4)
# Requirement already satisfied: setuptools in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\pauls\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: C:\Users\pauls\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %% [markdown]
# ##### Hint:
# The [space versus tabs](https://www.youtube.com/watch?v=SsoOG6ZeyUI&feature=emb_logo) war is a birthday party in comparison to breaking import guidelines.

# %% [markdown]
# ## Exploring the MNIST dataset
#
# Before any data science or machine learning project, it is essential to get to know your data. This will enable you to detect issues, noise, pitfalls and understand what your model will learn at the end of the day. With the MNIST dataset, you will be working with a beautiful, cleaned, easy to understand, low-memory, large-scale dataset.
# Full disclaimer, MNIST is excellent for learning and research purposes, yet this is not what you can expect in real-life.
#
# This initially becomes obvious as MNIST is so commonly used that the Keras packages got our back with loading the data in one line. We are loading pairs of samples and ground truth annotations for both the training set (for training our model) and the test set (for testing our model).
#
# <img src="graphics/jars.svg" width="650"><br>

# %%
# Loading the MNIST dataset in one line
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Printing the shape
print('x_train:', x_train.shape)
print('y_train:', y_train.shape)
print('x_test:', x_test.shape)
print('y_test:', y_test.shape)

# Plotting data samples
print('\n Plot of the first 25 samples in the MNIST training set')
numbers_to_display = 25
num_cells = math.ceil(math.sqrt(numbers_to_display))
plt.figure(figsize=(10,10))
for i in range(numbers_to_display):
    plt.subplot(num_cells, num_cells, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(y_train[i])
plt.show()
# Out:
# x_train: (60000, 28, 28)
# y_train: (60000,)
# x_test: (10000, 28, 28)
# y_test: (10000,)
#
#  Plot of the first 25 samples in the MNIST training set

# %% [markdown]
# The shape of the data arrays already gave away that we are using way more samples (60k) for training than for testing (10k). A typical ratio is 80% training and 20% testing as a rule of thumb. Actually, the 80% training is further split into the real training and a validation set, but that will not bother us here.
#
# [Deep dive on dataset generation, split and pitfalls (slide)](slides/slide_datasetgeneration.pdf)
#
# The other thing the shape gave away is the samples' dimensions $28x28x1$ and the dimension of the ground truth $1$.
#
# Along with the shape, we also plot the first 25 samples of the MNIST training set together with their ground truth labels (annotations). We can start to guess what the dataset is all about - it is a dataset purposed for digit recognition.
#
#
# ### Data preprocessing
# We already talked quite a bit about [activation functions](https://cs231n.github.io/neural-networks-1/) (or non-linearity) and how they take a single, usually accumulated, number and perform a specific fixed mathematical operation on it. There are quite different ones, but you will soon find out that there emerges a shared pattern within deep neural networks that makes them beneficial in practice.
#
# - They usually map any incoming value so that they are asymptotically bounded from above and below. For example, the [sigmoid function](https://en.wikipedia.org/wiki/Sigmoid_function) does map to a range of values between $0$ and $1$.
# They are usually most sensitive around zero because they tend to saturate to the bounds of the mapping for large numbers.
#
# Thus we can speed up the training process by preprocessing our data so that the first layer's activation function has an easier time picking up the pattern.
#
# For the MNIST, this is quickly done by normalizing the grayscale values $[0, 255]$ to a range between $[0, 1]$. Remember to do the preprocessing for both the training and the test samples.
#
#
# <img src="graphics/standardizedBeans.svg" width="700"><br>

# %%
x_train_normalized = x_train / 255
x_test_normalized = x_test / 255

# in the next step, we also need to reshape our input to fit our input layer later on. 
# This is due to keras expecting a definition for how many channels your input sample has, as we 
# deal with gray scale this is 1.
x_train= x_train_normalized.reshape(-1, 28, 28, 1)
x_test = x_test_normalized.reshape(-1, 28, 28, 1)

# %%
'''
 ____   __   __ _  __  ____  _  _     ___  _  _  ____  ___  __ _ 
/ ___) / _\ (  ( \(  )(_  _)( \/ )   / __)/ )( \(  __)/ __)(  / )
\___ \/    \/    / )(   )(   )  /   ( (__ ) __ ( ) _)( (__  )  ( 
(____/\_/\_/\_)__)(__) (__) (__/     \___)\_)(_/(____)\___)(__\_)

Do not touch, just run!
'''
checker.test_normalize(x_train, x_train_normalized)
# Out:
# Normalization worked out well, you are ready to go.

# %% [markdown]
# ##### Hint:
# In python a division can be done like this in python:  $3, 5~/~ 2 == 2.5$ <br>

# %% [markdown]
# ## Designing the neural network architecture
#
# Remember how much work it was to set up a single neuron - right. Now enjoy how Keras is helping you with this. We will call our neural network [marvin](https://en.wikipedia.org/wiki/Marvin_the_Paranoid_Android). Feel free to change it to whatever you like, in case you are not okay with it.
#
# Our model will follow some design requirements, it will be [sequential](https://www.tensorflow.org/api_docs/python/tf/keras/Sequential?version=stable) or it other words, feed forward, meaning that once a value passed through a unit, the unit will not see a value during that forward pass again. Or in other words, we do not have any recurrence in the architecture (feedback loops and so on).
#
# That's a lot to tackle, there will be quite some hyperparameters. This is for the visual learner - need a sandbox before we get started? I got your back [tensorflow sandbox](http://playground.tensorflow.org)
#
# I really encourage you to take the time to play in the sandbox. It's worth to build up some intuition. At least play with the number of layers and the number of units per layer. Observe how the features increase in complexity the deeper you go with your layers.

# %%
# This is the moment where you define your model's architecture

x_train = x_train[1:5000]
y_train = y_train[1:5000]

marvin = tf.keras.models.Sequential()

marvin.add(tf.keras.layers.Conv2D(16, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
marvin.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
marvin.add(tf.keras.layers.Conv2D(8, kernel_size=(3, 3), activation='relu'))
marvin.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
marvin.add(tf.keras.layers.Dropout(0.5))
marvin.add(tf.keras.layers.Flatten())
marvin.add(tf.keras.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Adding layers to Marvin is as easy as adding a layer while handing over that layer's specification. In the end, the layers will be stacked following the order in which your code gets compiled.
#
# Initially, we need an input layer, which can take in our input samples. Go ahead and set up a 2D convolutional layer, with an input shape fitting our image samples, with a kernel size of 5, 8 channels or filters, a stride of 1, and an activation function that does identity mapping, to begin with.

# %%
# “Don't blame you," said Marvin and counted five hundred and ninety-seven thousand million sheep 
# before falling asleep again a second later.”


marvin.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 16)        160
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 8)         1160
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 8)           0
#  g2D)
#
#  dropout (Dropout)           (None, 5, 5, 8)           0
#
#  flatten (Flatten)           (None, 200)               0
#
#  dense (Dense)               (None, 10)                2010
#
# =================================================================
# Total params: 3330 (13.01 KB)
# Trainable params: 3330 (13.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##### Hint:
# Find out about Keras activation functions [here](https://keras.io/api/layers/activations/) and about layers [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers). The input shape only needs to be defined for the input layer. Using softmax in your output layer will give you the pleasant effect of a probability distribution for your prediction. The output of softmax transformation has all values non-negative and sum to 1.
#
# <br>
#
# Keep on designing your model until your model summary is the same as this one:
#
# ![image-2.png](attachment:image-2.png)
#
#
# ##### Side Quest:
# Come back once you finished training your model, and try adding layers and playing around with different layer types.

# %% [markdown]
# ## Designing the neural network training
#
# Great, that's it. Take a moment to realize how quickly and with how much ease (maybe not during the first time) you designed this architecture with $67k$ parameters. Also, within the blink of an eye, you created a neural network that has more neurons than a box jellyfish ($17.5k$ neurons), a sea slug ($18k$), coming in behind the fruitfly ($250k$). To put things into perspective, humans come in second with ($8.6\times10^{10}$) neurons, only surpassed by the African elephant. Find a full list [here](https://en.wikipedia.org/wiki/List_of_animals_by_number_of_neurons).
#
# Next, we need to train Marvin to assign a class prediction when we hand him over a sample of a digit.
#
# Remember, when we set up our loss function and learning rate? That's precisely what we are going to do here as well, yet again with the help of Keras.
#
#
# <img src="graphics/blackCoffee.svg" width="500"><br>

# %%
# Define your loss
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)


print(-tf.math.log(1/10))

sampleID = 100
loss_fn(y_train[:1], marvin(x_train[sampleID-1:sampleID]).numpy()).numpy()
# Out:
# tf.Tensor(2.3025851, shape=(), dtype=float32)
# 2.3198428

# %% [markdown]
# The loss is crucial for your training. The better your loss reflects the actual objective of your model the more efficient it will converge to the optimal parameter set.
#
# The loss is also great to check whether your model behaves as expected. The SparseCategoricalCrossentropy is equal to the negative log probability of the true class: The loss is zero if the model is sure of the correct class.
#
# Your untrained model gives probabilities close to random (1/10 for each class,  as there are 10 digits), so the initial loss should be close to:
#
# -tf.math.log(1/10) ~= 2.3
#
# Obviously different samples will give different losses, play with the sampleID to observe the changes.
#
#
# <img src="graphics/grinder.svg" width="700"><br>

# %%
# Compiling basically means to prepare the training routine for your model which consists of the optimizer, 
# the loss, and the metrics which are to be reported during training

marvin.compile(optimizer='adam',
              loss= loss_fn,
              metrics=['accuracy'])

# %% [markdown]
# ##### Hint:
# Make sure you understand the difference between a [metric](https://keras.io/api/metrics/) (only tells you how good your neural network performs) and a [loss](https://keras.io/api/losses/) (tells you how your model performance, but also directly tells your model how to update its weights to improve performance). <br>
#
#
# ##### Side Quest:
# Feel free to play around with your neural network and the learning configuration.
# Great places to start are:
# - The [optimizer](https://keras.io/api/optimizers/), the losses, the metrics.
# - Adding layers, changing Kernel sizes, strides, and activation functions.
# - You might have guessed the learning rate. Truth be told, playing around with each hyperparameter will get you some experience and intuition for its behavior.

# %%
# Here is some space for you to write down your thoughts on the side quest questions and experiments

...
# Out:
# Ellipsis

# %% [markdown]
# 😅 Grinning Face with Sweat

# %% [markdown]
# ## Train, the model
#
# Now it is time to plug our data into Marvin and let him learn to recognize the digit within an image sample. Besides plugging in the data, and the labels, we need to let Keras know how long we want to train Marvin. In deep learning, training on each sample of the training set precisely ones is called an epoch.
# Obviously, the longer you train, the better your model will fit the underlying pattern. Then you can also set how many samples Marvin will see during each update step (this is called batch size). The more samples, the better the gradient approximation, but at some point, you will also run into hardware limitations.
#
# Yet, remember that it is the unseen data of your validation set that machine learning approaches are after. This is also what lets deep learning stand out from pure optimization.
#
#
# <img src="graphics/machine.svg" width="800"><br>

# %%
# import datetime
# import os
# %load_ext tensorboard


# logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
# tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# %% [markdown]
# Tensorboard is great for versioning, sharing and analyzing your trainings through logs and tensorboards visualization as you will experience soon enough. Sad enough tensorboard is not eagerly supported by binder. But you get the idea [here](https://www.tensorflow.org/tensorboard).

# %%
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_accuracy",
    min_delta=0,
    patience=60,
    verbose=0,
    mode="auto",
    )

# Füge den Callback zur Liste der Callbacks hinzu
callbacks_list = [early_stopping_callback]

# Verwende die Callbacks-Liste im fit-Aufruf
marvin.fit(
    x_train,
    y_train,
    epochs=300,
    batch_size=32,
    validation_data=(x_test, y_test),
    shuffle=True,
    validation_split=0.1,
    callbacks=callbacks_list  # Hier wird die Liste der Callbacks übergeben
)
# Out:
# Epoch 1/300
# C:\Users\pauls\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:5729: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 157/157 [==============================] - 6s 33ms/step - loss: 1.7486 - accuracy: 0.4051 - val_loss: 0.6682 - val_accuracy: 0.8575
# Epoch 2/300
# 157/157 [==============================] - 5s 31ms/step - loss: 0.7325 - accuracy: 0.7698 - val_loss: 0.3714 - val_accuracy: 0.9029
# Epoch 3/300
# 157/157 [==============================] - 5s 30ms/step - loss: 0.5624 - accuracy: 0.8286 - val_loss: 0.3057 - val_accuracy: 0.9205
# Epoch 4/300
# 157/157 [==============================] - 5s 31ms/step - loss: 0.4631 - accuracy: 0.8618 - val_loss: 0.2474 - val_accuracy: 0.9331
# Epoch 5/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.4033 - accuracy: 0.8778 - val_loss: 0.2193 - val_accuracy: 0.9386
# Epoch 6/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.3768 - accuracy: 0.8798 - val_loss: 0.2067 - val_accuracy: 0.9435
# Epoch 7/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.3288 - accuracy: 0.9002 - val_loss: 0.1852 - val_accuracy: 0.9491
# Epoch 8/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.3108 - accuracy: 0.9052 - val_loss: 0.1749 - val_accuracy: 0.9517
# Epoch 9/300
# 157/157 [==============================] - 5s 30ms/step - loss: 0.2890 - accuracy: 0.9108 - val_loss: 0.1576 - val_accuracy: 0.9571
# Epoch 10/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.2748 - accuracy: 0.9162 - val_loss: 0.1523 - val_accuracy: 0.9579
# Epoch 11/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.2640 - accuracy: 0.9190 - val_loss: 0.1463 - val_accuracy: 0.9571
# Epoch 12/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.2432 - accuracy: 0.9266 - val_loss: 0.1384 - val_accuracy: 0.9604
# Epoch 13/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.2450 - accuracy: 0.9238 - val_loss: 0.1323 - val_accuracy: 0.9607
# Epoch 14/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.2267 - accuracy: 0.9304 - val_loss: 0.1309 - val_accuracy: 0.9627
# Epoch 15/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.2284 - accuracy: 0.9266 - val_loss: 0.1381 - val_accuracy: 0.9586
# Epoch 16/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.2188 - accuracy: 0.9344 - val_loss: 0.1169 - val_accuracy: 0.9643
# Epoch 17/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.2140 - accuracy: 0.9298 - val_loss: 0.1237 - val_accuracy: 0.9628
# Epoch 18/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.2104 - accuracy: 0.9336 - val_loss: 0.1128 - val_accuracy: 0.9650
# Epoch 19/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1956 - accuracy: 0.9402 - val_loss: 0.1082 - val_accuracy: 0.9665
# Epoch 20/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1875 - accuracy: 0.9394 - val_loss: 0.1096 - val_accuracy: 0.9663
# Epoch 21/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1965 - accuracy: 0.9382 - val_loss: 0.1024 - val_accuracy: 0.9683
# Epoch 22/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1962 - accuracy: 0.9348 - val_loss: 0.1018 - val_accuracy: 0.9684
# Epoch 23/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1803 - accuracy: 0.9476 - val_loss: 0.1021 - val_accuracy: 0.9679
# Epoch 24/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1796 - accuracy: 0.9426 - val_loss: 0.1001 - val_accuracy: 0.9691
# Epoch 25/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1827 - accuracy: 0.9418 - val_loss: 0.0989 - val_accuracy: 0.9693
# Epoch 26/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1803 - accuracy: 0.9456 - val_loss: 0.0915 - val_accuracy: 0.9705
# Epoch 27/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1638 - accuracy: 0.9472 - val_loss: 0.0976 - val_accuracy: 0.9684
# Epoch 28/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.1807 - accuracy: 0.9434 - val_loss: 0.0932 - val_accuracy: 0.9708
# Epoch 29/300
# 157/157 [==============================] - 4s 26ms/step - loss: 0.1620 - accuracy: 0.9470 - val_loss: 0.0949 - val_accuracy: 0.9705
# Epoch 30/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1602 - accuracy: 0.9490 - val_loss: 0.0929 - val_accuracy: 0.9702
# Epoch 31/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1608 - accuracy: 0.9480 - val_loss: 0.0906 - val_accuracy: 0.9704
# Epoch 32/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1548 - accuracy: 0.9532 - val_loss: 0.0886 - val_accuracy: 0.9718
# Epoch 33/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1602 - accuracy: 0.9472 - val_loss: 0.0882 - val_accuracy: 0.9730
# Epoch 34/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1681 - accuracy: 0.9498 - val_loss: 0.0888 - val_accuracy: 0.9729
# Epoch 35/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1638 - accuracy: 0.9468 - val_loss: 0.0877 - val_accuracy: 0.9721
# Epoch 36/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1585 - accuracy: 0.9484 - val_loss: 0.0847 - val_accuracy: 0.9730
# Epoch 37/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.1500 - accuracy: 0.9510 - val_loss: 0.0831 - val_accuracy: 0.9737
# Epoch 38/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1531 - accuracy: 0.9500 - val_loss: 0.0843 - val_accuracy: 0.9725
# Epoch 39/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1525 - accuracy: 0.9528 - val_loss: 0.0814 - val_accuracy: 0.9742
# Epoch 40/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1387 - accuracy: 0.9576 - val_loss: 0.0823 - val_accuracy: 0.9736
# Epoch 41/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.1376 - accuracy: 0.9540 - val_loss: 0.0791 - val_accuracy: 0.9748
# Epoch 42/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.1464 - accuracy: 0.9530 - val_loss: 0.0806 - val_accuracy: 0.9745
# Epoch 43/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1506 - accuracy: 0.9540 - val_loss: 0.0810 - val_accuracy: 0.9744
# Epoch 44/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1394 - accuracy: 0.9566 - val_loss: 0.0809 - val_accuracy: 0.9733
# Epoch 45/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1463 - accuracy: 0.9518 - val_loss: 0.0818 - val_accuracy: 0.9740
# Epoch 46/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1334 - accuracy: 0.9594 - val_loss: 0.0776 - val_accuracy: 0.9756
# Epoch 47/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1455 - accuracy: 0.9522 - val_loss: 0.0816 - val_accuracy: 0.9736
# Epoch 48/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1341 - accuracy: 0.9550 - val_loss: 0.0813 - val_accuracy: 0.9746
# Epoch 49/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1382 - accuracy: 0.9536 - val_loss: 0.0800 - val_accuracy: 0.9743
# Epoch 50/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.1458 - accuracy: 0.9552 - val_loss: 0.0783 - val_accuracy: 0.9744
# Epoch 51/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.1237 - accuracy: 0.9598 - val_loss: 0.0775 - val_accuracy: 0.9758
# Epoch 52/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1353 - accuracy: 0.9546 - val_loss: 0.0756 - val_accuracy: 0.9757
# Epoch 53/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1351 - accuracy: 0.9574 - val_loss: 0.0767 - val_accuracy: 0.9754
# Epoch 54/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1259 - accuracy: 0.9598 - val_loss: 0.0791 - val_accuracy: 0.9747
# Epoch 55/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1285 - accuracy: 0.9598 - val_loss: 0.0749 - val_accuracy: 0.9756
# Epoch 56/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1297 - accuracy: 0.9604 - val_loss: 0.0797 - val_accuracy: 0.9747
# Epoch 57/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1385 - accuracy: 0.9558 - val_loss: 0.0769 - val_accuracy: 0.9763
# Epoch 58/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1361 - accuracy: 0.9588 - val_loss: 0.0753 - val_accuracy: 0.9754
# Epoch 59/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.1271 - accuracy: 0.9600 - val_loss: 0.0744 - val_accuracy: 0.9758
# Epoch 60/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1267 - accuracy: 0.9616 - val_loss: 0.0762 - val_accuracy: 0.9756
# Epoch 61/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1296 - accuracy: 0.9572 - val_loss: 0.0762 - val_accuracy: 0.9752
# Epoch 62/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1346 - accuracy: 0.9560 - val_loss: 0.0759 - val_accuracy: 0.9746
# Epoch 63/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1179 - accuracy: 0.9618 - val_loss: 0.0729 - val_accuracy: 0.9760
# Epoch 64/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1174 - accuracy: 0.9626 - val_loss: 0.0732 - val_accuracy: 0.9764
# Epoch 65/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1219 - accuracy: 0.9604 - val_loss: 0.0760 - val_accuracy: 0.9760
# Epoch 66/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1181 - accuracy: 0.9654 - val_loss: 0.0717 - val_accuracy: 0.9764
# Epoch 67/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.1334 - accuracy: 0.9554 - val_loss: 0.0776 - val_accuracy: 0.9753
# Epoch 68/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.1193 - accuracy: 0.9618 - val_loss: 0.0738 - val_accuracy: 0.9761
# Epoch 69/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.1173 - accuracy: 0.9632 - val_loss: 0.0720 - val_accuracy: 0.9770
# Epoch 70/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.1224 - accuracy: 0.9600 - val_loss: 0.0716 - val_accuracy: 0.9767
# Epoch 71/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1151 - accuracy: 0.9614 - val_loss: 0.0701 - val_accuracy: 0.9774
# Epoch 72/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1312 - accuracy: 0.9588 - val_loss: 0.0744 - val_accuracy: 0.9763
# Epoch 73/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1222 - accuracy: 0.9612 - val_loss: 0.0736 - val_accuracy: 0.9763
# Epoch 74/300
# 157/157 [==============================] - 4s 26ms/step - loss: 0.1050 - accuracy: 0.9660 - val_loss: 0.0736 - val_accuracy: 0.9764
# Epoch 75/300
# 157/157 [==============================] - 4s 26ms/step - loss: 0.1133 - accuracy: 0.9664 - val_loss: 0.0739 - val_accuracy: 0.9770
# Epoch 76/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1105 - accuracy: 0.9646 - val_loss: 0.0712 - val_accuracy: 0.9776
# Epoch 77/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1199 - accuracy: 0.9590 - val_loss: 0.0750 - val_accuracy: 0.9763
# Epoch 78/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1084 - accuracy: 0.9664 - val_loss: 0.0732 - val_accuracy: 0.9769
# Epoch 79/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1183 - accuracy: 0.9628 - val_loss: 0.0724 - val_accuracy: 0.9769
# Epoch 80/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1158 - accuracy: 0.9604 - val_loss: 0.0733 - val_accuracy: 0.9760
# Epoch 81/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1205 - accuracy: 0.9606 - val_loss: 0.0700 - val_accuracy: 0.9770
# Epoch 82/300
# 157/157 [==============================] - 4s 26ms/step - loss: 0.1183 - accuracy: 0.9624 - val_loss: 0.0717 - val_accuracy: 0.9763
# Epoch 83/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1118 - accuracy: 0.9640 - val_loss: 0.0711 - val_accuracy: 0.9766
# Epoch 84/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.1110 - accuracy: 0.9652 - val_loss: 0.0709 - val_accuracy: 0.9768
# Epoch 85/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1162 - accuracy: 0.9630 - val_loss: 0.0749 - val_accuracy: 0.9756
# Epoch 86/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.1083 - accuracy: 0.9610 - val_loss: 0.0716 - val_accuracy: 0.9770
# Epoch 87/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.1068 - accuracy: 0.9662 - val_loss: 0.0713 - val_accuracy: 0.9769
# Epoch 88/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.1039 - accuracy: 0.9698 - val_loss: 0.0687 - val_accuracy: 0.9778
# Epoch 89/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1110 - accuracy: 0.9652 - val_loss: 0.0721 - val_accuracy: 0.9767
# Epoch 90/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1088 - accuracy: 0.9664 - val_loss: 0.0715 - val_accuracy: 0.9777
# Epoch 91/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1184 - accuracy: 0.9614 - val_loss: 0.0702 - val_accuracy: 0.9769
# Epoch 92/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.1143 - accuracy: 0.9642 - val_loss: 0.0706 - val_accuracy: 0.9765
# Epoch 93/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.1099 - accuracy: 0.9654 - val_loss: 0.0712 - val_accuracy: 0.9781
# Epoch 94/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.1244 - accuracy: 0.9624 - val_loss: 0.0709 - val_accuracy: 0.9771
# Epoch 95/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1025 - accuracy: 0.9650 - val_loss: 0.0707 - val_accuracy: 0.9772
# Epoch 96/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1132 - accuracy: 0.9626 - val_loss: 0.0705 - val_accuracy: 0.9779
# Epoch 97/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1154 - accuracy: 0.9616 - val_loss: 0.0697 - val_accuracy: 0.9774
# Epoch 98/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1045 - accuracy: 0.9696 - val_loss: 0.0690 - val_accuracy: 0.9779
# Epoch 99/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1004 - accuracy: 0.9664 - val_loss: 0.0703 - val_accuracy: 0.9781
# Epoch 100/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1117 - accuracy: 0.9634 - val_loss: 0.0730 - val_accuracy: 0.9777
# Epoch 101/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1090 - accuracy: 0.9636 - val_loss: 0.0660 - val_accuracy: 0.9790
# Epoch 102/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.1065 - accuracy: 0.9634 - val_loss: 0.0706 - val_accuracy: 0.9785
# Epoch 103/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1126 - accuracy: 0.9648 - val_loss: 0.0708 - val_accuracy: 0.9785
# Epoch 104/300
# 157/157 [==============================] - 4s 26ms/step - loss: 0.1086 - accuracy: 0.9632 - val_loss: 0.0714 - val_accuracy: 0.9779
# Epoch 105/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1116 - accuracy: 0.9658 - val_loss: 0.0667 - val_accuracy: 0.9781
# Epoch 106/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1013 - accuracy: 0.9670 - val_loss: 0.0673 - val_accuracy: 0.9787
# Epoch 107/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0986 - accuracy: 0.9690 - val_loss: 0.0674 - val_accuracy: 0.9786
# Epoch 108/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1081 - accuracy: 0.9666 - val_loss: 0.0690 - val_accuracy: 0.9784
# Epoch 109/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1007 - accuracy: 0.9676 - val_loss: 0.0677 - val_accuracy: 0.9787
# Epoch 110/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1050 - accuracy: 0.9662 - val_loss: 0.0693 - val_accuracy: 0.9782
# Epoch 111/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.0985 - accuracy: 0.9666 - val_loss: 0.0709 - val_accuracy: 0.9779
# Epoch 112/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1036 - accuracy: 0.9654 - val_loss: 0.0681 - val_accuracy: 0.9786
# Epoch 113/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0976 - accuracy: 0.9698 - val_loss: 0.0700 - val_accuracy: 0.9782
# Epoch 114/300
# 157/157 [==============================] - 5s 29ms/step - loss: 0.0971 - accuracy: 0.9680 - val_loss: 0.0695 - val_accuracy: 0.9776
# Epoch 115/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0986 - accuracy: 0.9690 - val_loss: 0.0687 - val_accuracy: 0.9786
# Epoch 116/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.0940 - accuracy: 0.9674 - val_loss: 0.0702 - val_accuracy: 0.9780
# Epoch 117/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.0976 - accuracy: 0.9664 - val_loss: 0.0665 - val_accuracy: 0.9792
# Epoch 118/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0958 - accuracy: 0.9706 - val_loss: 0.0656 - val_accuracy: 0.9791
# Epoch 119/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1049 - accuracy: 0.9688 - val_loss: 0.0678 - val_accuracy: 0.9788
# Epoch 120/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0981 - accuracy: 0.9708 - val_loss: 0.0673 - val_accuracy: 0.9781
# Epoch 121/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0904 - accuracy: 0.9704 - val_loss: 0.0741 - val_accuracy: 0.9773
# Epoch 122/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0918 - accuracy: 0.9712 - val_loss: 0.0689 - val_accuracy: 0.9776
# Epoch 123/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1011 - accuracy: 0.9666 - val_loss: 0.0742 - val_accuracy: 0.9778
# Epoch 124/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0913 - accuracy: 0.9724 - val_loss: 0.0710 - val_accuracy: 0.9786
# Epoch 125/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0925 - accuracy: 0.9690 - val_loss: 0.0702 - val_accuracy: 0.9779
# Epoch 126/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1007 - accuracy: 0.9664 - val_loss: 0.0693 - val_accuracy: 0.9786
# Epoch 127/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0970 - accuracy: 0.9704 - val_loss: 0.0687 - val_accuracy: 0.9785
# Epoch 128/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0967 - accuracy: 0.9694 - val_loss: 0.0696 - val_accuracy: 0.9784
# Epoch 129/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1018 - accuracy: 0.9672 - val_loss: 0.0692 - val_accuracy: 0.9782
# Epoch 130/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0983 - accuracy: 0.9672 - val_loss: 0.0668 - val_accuracy: 0.9789
# Epoch 131/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0935 - accuracy: 0.9688 - val_loss: 0.0661 - val_accuracy: 0.9790
# Epoch 132/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0904 - accuracy: 0.9688 - val_loss: 0.0694 - val_accuracy: 0.9783
# Epoch 133/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0947 - accuracy: 0.9706 - val_loss: 0.0682 - val_accuracy: 0.9783
# Epoch 134/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0994 - accuracy: 0.9670 - val_loss: 0.0696 - val_accuracy: 0.9784
# Epoch 135/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0940 - accuracy: 0.9692 - val_loss: 0.0715 - val_accuracy: 0.9787
# Epoch 136/300
# 157/157 [==============================] - 4s 26ms/step - loss: 0.1006 - accuracy: 0.9672 - val_loss: 0.0671 - val_accuracy: 0.9803
# Epoch 137/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0958 - accuracy: 0.9712 - val_loss: 0.0676 - val_accuracy: 0.9793
# Epoch 138/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0824 - accuracy: 0.9710 - val_loss: 0.0657 - val_accuracy: 0.9791
# Epoch 139/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0951 - accuracy: 0.9708 - val_loss: 0.0667 - val_accuracy: 0.9798
# Epoch 140/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0927 - accuracy: 0.9696 - val_loss: 0.0639 - val_accuracy: 0.9797
# Epoch 141/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0949 - accuracy: 0.9686 - val_loss: 0.0647 - val_accuracy: 0.9799
# Epoch 142/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0853 - accuracy: 0.9712 - val_loss: 0.0690 - val_accuracy: 0.9787
# Epoch 143/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0863 - accuracy: 0.9724 - val_loss: 0.0718 - val_accuracy: 0.9775
# Epoch 144/300
# 157/157 [==============================] - 4s 26ms/step - loss: 0.0968 - accuracy: 0.9702 - val_loss: 0.0677 - val_accuracy: 0.9791
# Epoch 145/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0864 - accuracy: 0.9728 - val_loss: 0.0652 - val_accuracy: 0.9798
# Epoch 146/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.1002 - accuracy: 0.9670 - val_loss: 0.0667 - val_accuracy: 0.9788
# Epoch 147/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0920 - accuracy: 0.9684 - val_loss: 0.0664 - val_accuracy: 0.9790
# Epoch 148/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0936 - accuracy: 0.9676 - val_loss: 0.0664 - val_accuracy: 0.9794
# Epoch 149/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0987 - accuracy: 0.9690 - val_loss: 0.0666 - val_accuracy: 0.9791
# Epoch 150/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0868 - accuracy: 0.9704 - val_loss: 0.0661 - val_accuracy: 0.9794
# Epoch 151/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0891 - accuracy: 0.9712 - val_loss: 0.0679 - val_accuracy: 0.9790
# Epoch 152/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0978 - accuracy: 0.9706 - val_loss: 0.0678 - val_accuracy: 0.9787
# Epoch 153/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0906 - accuracy: 0.9706 - val_loss: 0.0661 - val_accuracy: 0.9791
# Epoch 154/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.0854 - accuracy: 0.9718 - val_loss: 0.0668 - val_accuracy: 0.9793
# Epoch 155/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0871 - accuracy: 0.9690 - val_loss: 0.0702 - val_accuracy: 0.9791
# Epoch 156/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0888 - accuracy: 0.9712 - val_loss: 0.0692 - val_accuracy: 0.9792
# Epoch 157/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0873 - accuracy: 0.9714 - val_loss: 0.0686 - val_accuracy: 0.9791
# Epoch 158/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.1014 - accuracy: 0.9676 - val_loss: 0.0671 - val_accuracy: 0.9796
# Epoch 159/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0861 - accuracy: 0.9712 - val_loss: 0.0669 - val_accuracy: 0.9807
# Epoch 160/300
# 157/157 [==============================] - 4s 29ms/step - loss: 0.0911 - accuracy: 0.9714 - val_loss: 0.0693 - val_accuracy: 0.9797
# Epoch 161/300
# 157/157 [==============================] - 4s 25ms/step - loss: 0.0969 - accuracy: 0.9694 - val_loss: 0.0678 - val_accuracy: 0.9792
# Epoch 162/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0854 - accuracy: 0.9724 - val_loss: 0.0667 - val_accuracy: 0.9792
# Epoch 163/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0928 - accuracy: 0.9700 - val_loss: 0.0681 - val_accuracy: 0.9795
# Epoch 164/300
# 157/157 [==============================] - 4s 25ms/step - loss: 0.0969 - accuracy: 0.9698 - val_loss: 0.0671 - val_accuracy: 0.9789
# Epoch 165/300
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0974 - accuracy: 0.9710 - val_loss: 0.0648 - val_accuracy: 0.9795
# Epoch 166/300
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0960 - accuracy: 0.9696 - val_loss: 0.0642 - val_accuracy: 0.9804
# Epoch 167/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0918 - accuracy: 0.9688 - val_loss: 0.0656 - val_accuracy: 0.9795
# Epoch 168/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0960 - accuracy: 0.9700 - val_loss: 0.0669 - val_accuracy: 0.9796
# Epoch 169/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0880 - accuracy: 0.9712 - val_loss: 0.0669 - val_accuracy: 0.9795
# Epoch 170/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0917 - accuracy: 0.9702 - val_loss: 0.0654 - val_accuracy: 0.9792
# Epoch 171/300
# 157/157 [==============================] - 4s 26ms/step - loss: 0.0907 - accuracy: 0.9712 - val_loss: 0.0645 - val_accuracy: 0.9793
# Epoch 172/300
# 157/157 [==============================] - 4s 25ms/step - loss: 0.0877 - accuracy: 0.9716 - val_loss: 0.0651 - val_accuracy: 0.9798
# Epoch 173/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0898 - accuracy: 0.9704 - val_loss: 0.0657 - val_accuracy: 0.9797
# Epoch 174/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0823 - accuracy: 0.9720 - val_loss: 0.0627 - val_accuracy: 0.9808
# Epoch 175/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0978 - accuracy: 0.9660 - val_loss: 0.0687 - val_accuracy: 0.9789
# Epoch 176/300
# 157/157 [==============================] - 4s 26ms/step - loss: 0.0819 - accuracy: 0.9734 - val_loss: 0.0647 - val_accuracy: 0.9797
# Epoch 177/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0874 - accuracy: 0.9698 - val_loss: 0.0638 - val_accuracy: 0.9805
# Epoch 178/300
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0908 - accuracy: 0.9702 - val_loss: 0.0703 - val_accuracy: 0.9781
# Epoch 179/300
# 157/157 [==============================] - 4s 25ms/step - loss: 0.0877 - accuracy: 0.9730 - val_loss: 0.0652 - val_accuracy: 0.9796
# Epoch 180/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0776 - accuracy: 0.9732 - val_loss: 0.0710 - val_accuracy: 0.9783
# Epoch 181/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0879 - accuracy: 0.9698 - val_loss: 0.0671 - val_accuracy: 0.9807
# Epoch 182/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0871 - accuracy: 0.9704 - val_loss: 0.0659 - val_accuracy: 0.9791
# Epoch 183/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0752 - accuracy: 0.9746 - val_loss: 0.0653 - val_accuracy: 0.9801
# Epoch 184/300
# 157/157 [==============================] - 4s 26ms/step - loss: 0.0896 - accuracy: 0.9722 - val_loss: 0.0695 - val_accuracy: 0.9790
# Epoch 185/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0852 - accuracy: 0.9700 - val_loss: 0.0663 - val_accuracy: 0.9797
# Epoch 186/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0770 - accuracy: 0.9734 - val_loss: 0.0692 - val_accuracy: 0.9802
# Epoch 187/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0777 - accuracy: 0.9722 - val_loss: 0.0645 - val_accuracy: 0.9805
# Epoch 188/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0884 - accuracy: 0.9696 - val_loss: 0.0665 - val_accuracy: 0.9797
# Epoch 189/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0837 - accuracy: 0.9708 - val_loss: 0.0634 - val_accuracy: 0.9809
# Epoch 190/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0789 - accuracy: 0.9758 - val_loss: 0.0672 - val_accuracy: 0.9792
# Epoch 191/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0847 - accuracy: 0.9716 - val_loss: 0.0656 - val_accuracy: 0.9796
# Epoch 192/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0850 - accuracy: 0.9752 - val_loss: 0.0637 - val_accuracy: 0.9801
# Epoch 193/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0835 - accuracy: 0.9704 - val_loss: 0.0708 - val_accuracy: 0.9796
# Epoch 194/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0850 - accuracy: 0.9700 - val_loss: 0.0639 - val_accuracy: 0.9801
# Epoch 195/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0832 - accuracy: 0.9726 - val_loss: 0.0646 - val_accuracy: 0.9804
# Epoch 196/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0833 - accuracy: 0.9694 - val_loss: 0.0631 - val_accuracy: 0.9808
# Epoch 197/300
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0722 - accuracy: 0.9758 - val_loss: 0.0627 - val_accuracy: 0.9819
# Epoch 198/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0851 - accuracy: 0.9722 - val_loss: 0.0665 - val_accuracy: 0.9797
# Epoch 199/300
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0815 - accuracy: 0.9736 - val_loss: 0.0677 - val_accuracy: 0.9794
# Epoch 200/300
# 157/157 [==============================] - 4s 24ms/step - loss: 0.0837 - accuracy: 0.9732 - val_loss: 0.0654 - val_accuracy: 0.9805
# Epoch 201/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0829 - accuracy: 0.9726 - val_loss: 0.0643 - val_accuracy: 0.9809
# Epoch 202/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0850 - accuracy: 0.9736 - val_loss: 0.0641 - val_accuracy: 0.9804
# Epoch 203/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0860 - accuracy: 0.9734 - val_loss: 0.0674 - val_accuracy: 0.9791
# Epoch 204/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0761 - accuracy: 0.9746 - val_loss: 0.0666 - val_accuracy: 0.9802
# Epoch 205/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0913 - accuracy: 0.9698 - val_loss: 0.0664 - val_accuracy: 0.9804
# Epoch 206/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0771 - accuracy: 0.9740 - val_loss: 0.0666 - val_accuracy: 0.9800
# Epoch 207/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0880 - accuracy: 0.9686 - val_loss: 0.0627 - val_accuracy: 0.9809
# Epoch 208/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0795 - accuracy: 0.9720 - val_loss: 0.0651 - val_accuracy: 0.9793
# Epoch 209/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0714 - accuracy: 0.9758 - val_loss: 0.0643 - val_accuracy: 0.9803
# Epoch 210/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0754 - accuracy: 0.9764 - val_loss: 0.0644 - val_accuracy: 0.9801
# Epoch 211/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0928 - accuracy: 0.9692 - val_loss: 0.0661 - val_accuracy: 0.9793
# Epoch 212/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0788 - accuracy: 0.9742 - val_loss: 0.0641 - val_accuracy: 0.9808
# Epoch 213/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0816 - accuracy: 0.9716 - val_loss: 0.0635 - val_accuracy: 0.9803
# Epoch 214/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0816 - accuracy: 0.9736 - val_loss: 0.0653 - val_accuracy: 0.9806
# Epoch 215/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0832 - accuracy: 0.9686 - val_loss: 0.0635 - val_accuracy: 0.9812
# Epoch 216/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0786 - accuracy: 0.9758 - val_loss: 0.0705 - val_accuracy: 0.9790
# Epoch 217/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0861 - accuracy: 0.9722 - val_loss: 0.0676 - val_accuracy: 0.9803
# Epoch 218/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0772 - accuracy: 0.9704 - val_loss: 0.0635 - val_accuracy: 0.9812
# Epoch 219/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0710 - accuracy: 0.9754 - val_loss: 0.0654 - val_accuracy: 0.9812
# Epoch 220/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0785 - accuracy: 0.9760 - val_loss: 0.0648 - val_accuracy: 0.9806
# Epoch 221/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0772 - accuracy: 0.9746 - val_loss: 0.0720 - val_accuracy: 0.9784
# Epoch 222/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0802 - accuracy: 0.9724 - val_loss: 0.0707 - val_accuracy: 0.9793
# Epoch 223/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0739 - accuracy: 0.9760 - val_loss: 0.0715 - val_accuracy: 0.9790
# Epoch 224/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0820 - accuracy: 0.9740 - val_loss: 0.0717 - val_accuracy: 0.9784
# Epoch 225/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0703 - accuracy: 0.9784 - val_loss: 0.0665 - val_accuracy: 0.9803
# Epoch 226/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0782 - accuracy: 0.9744 - val_loss: 0.0651 - val_accuracy: 0.9807
# Epoch 227/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0780 - accuracy: 0.9738 - val_loss: 0.0672 - val_accuracy: 0.9796
# Epoch 228/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0712 - accuracy: 0.9758 - val_loss: 0.0674 - val_accuracy: 0.9803
# Epoch 229/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0923 - accuracy: 0.9716 - val_loss: 0.0643 - val_accuracy: 0.9805
# Epoch 230/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0851 - accuracy: 0.9732 - val_loss: 0.0647 - val_accuracy: 0.9808
# Epoch 231/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0768 - accuracy: 0.9760 - val_loss: 0.0668 - val_accuracy: 0.9802
# Epoch 232/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0815 - accuracy: 0.9736 - val_loss: 0.0630 - val_accuracy: 0.9814
# Epoch 233/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0897 - accuracy: 0.9728 - val_loss: 0.0620 - val_accuracy: 0.9815
# Epoch 234/300
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0793 - accuracy: 0.9750 - val_loss: 0.0682 - val_accuracy: 0.9801
# Epoch 235/300
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0768 - accuracy: 0.9746 - val_loss: 0.0652 - val_accuracy: 0.9808
# Epoch 236/300
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0757 - accuracy: 0.9752 - val_loss: 0.0672 - val_accuracy: 0.9804
# Epoch 237/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0757 - accuracy: 0.9760 - val_loss: 0.0633 - val_accuracy: 0.9813
# Epoch 238/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0790 - accuracy: 0.9752 - val_loss: 0.0673 - val_accuracy: 0.9808
# Epoch 239/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0794 - accuracy: 0.9742 - val_loss: 0.0653 - val_accuracy: 0.9803
# Epoch 240/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0729 - accuracy: 0.9740 - val_loss: 0.0635 - val_accuracy: 0.9817
# Epoch 241/300
# 157/157 [==============================] - 3s 18ms/step - loss: 0.0875 - accuracy: 0.9702 - val_loss: 0.0708 - val_accuracy: 0.9794
# Epoch 242/300
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0792 - accuracy: 0.9726 - val_loss: 0.0677 - val_accuracy: 0.9800
# Epoch 243/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0790 - accuracy: 0.9716 - val_loss: 0.0633 - val_accuracy: 0.9817
# Epoch 244/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0778 - accuracy: 0.9736 - val_loss: 0.0654 - val_accuracy: 0.9817
# Epoch 245/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0859 - accuracy: 0.9708 - val_loss: 0.0663 - val_accuracy: 0.9814
# Epoch 246/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0837 - accuracy: 0.9700 - val_loss: 0.0670 - val_accuracy: 0.9805
# Epoch 247/300
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0789 - accuracy: 0.9752 - val_loss: 0.0663 - val_accuracy: 0.9813
# Epoch 248/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0794 - accuracy: 0.9746 - val_loss: 0.0671 - val_accuracy: 0.9811
# Epoch 249/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0875 - accuracy: 0.9694 - val_loss: 0.0634 - val_accuracy: 0.9814
# Epoch 250/300
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0900 - accuracy: 0.9728 - val_loss: 0.0667 - val_accuracy: 0.9801
# Epoch 251/300
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0717 - accuracy: 0.9778 - val_loss: 0.0659 - val_accuracy: 0.9810
# Epoch 252/300
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0797 - accuracy: 0.9728 - val_loss: 0.0672 - val_accuracy: 0.9804
# Epoch 253/300
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0700 - accuracy: 0.9776 - val_loss: 0.0644 - val_accuracy: 0.9808
# Epoch 254/300
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0827 - accuracy: 0.9720 - val_loss: 0.0657 - val_accuracy: 0.9812
# Epoch 255/300
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0730 - accuracy: 0.9750 - val_loss: 0.0684 - val_accuracy: 0.9802
# Epoch 256/300
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0770 - accuracy: 0.9754 - val_loss: 0.0647 - val_accuracy: 0.9810
# Epoch 257/300
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0652 - accuracy: 0.9800 - val_loss: 0.0665 - val_accuracy: 0.9800

# %%
# This line would start up tensorboard for you
# %tensorboard --logdir logs

# %% [markdown]
# ##### Hint:
# Even if you stop the training, the model's current state will be saved as long as your juypter notebook session is active. Also, there is more to specify for training within the fit function of Keras. Check it out [here](https://keras.io/api/models/model_training_apis/) <br>
#
# ##### Side Quest:
# Reach at least a validation performance of $98 \%$ or higher before moving on. To achieve this, you are free to change whatever you want within the architecture and training process. Obviously, better performance is an excellent achievement. Further add at least one more argument to the fit routine. In case you are looking for further guidance how to progress with setting up your training pipeline [look no further](https://cs231n.github.io/neural-networks-3/).

# %%
# after the training finishes, we will also save Marvin in Keras style (HDF5), so we do not have to 
# train him again
# every time we start our computer. Obviously, by changing the model_name, you can also save different
# configurations of Marvin. The name has to be a string, like this: 'name.h5'
model_name = 'Versuch3_32.h5'
marvin.save(model_name, save_format='h5')

# It is best practice to indicate what configuration changes you did within the name, so you know
# which model you need to load already from its name
# Let's say instead of a learning rate of 0.001 you used 0.1, your naming could then look like:
# 'marvin_lr01.h5'

print('Success! You saved Marvin as: ', model_name)
# Out:
# Success! You saved Marvin as:  Versuch3_32.h5
# C:\Users\pauls\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## Evaluating Marvin
#
# Yes, you are right. The job is basically done. Marvin has been trained, and you also made sure that the model recognizes more than $98 \%$ of the unseen samples correctly. Would you say that you know what Marvin learned or what exactly he is capable of in the end? I do not want to spoil it for you, but in real life the hard task begins right after training a model - propper validation is key. Especially in safety critical systems. And there are enough [incidents](https://incidentdatabase.ai/) to demonstrate how models can fail and why it is so hard to prevent these failures.
#
# #### Side Quest:
# Try to answer the following questions:
#
# - Which digit is hardest for Marvin to predict correctly?
# - Which two digits does Marvin confuse most often?
# - Which digit does he perform best in?
# - How do digits look that Marvin was not able to predict correctly? Can you see why?
#
# These questions are hard to answer and clarify that an in depth analysis of the model's performance is paramount. I like a mix of visualization (which helps my intuition) and number crushing (which helps to write reports and prove my intuition with hard and cold numbers).
#
# So in the following, we will go ahead and answer some of the questions mentioned above. Along the way, you will learn some strategies to evaluate your neural network.
#
# The worse your model is the easier it will be to pick up effects in your validation, so feel free to either save a random model or a model that has only been trained for a few iterations and use this model in the following.
#
# <img src="graphics/stars.svg" width="500"><br>

# %% [markdown]
# 😆 Grinning Squinting Face

# %%
# Here is some space for you to write down your thoughts on the side quest questions and experiments

...
# Out:
# Ellipsis

# %% [markdown]
# ### The Intuitive Approach
#
# We will start with the intuition building approach. The following code will plot the image samples. The caption below is Marvin's prediction. If he is right, the sample will get a greenish touch. If he is wrong, a reddish one. Try to answer the above questions with the results from the intuitive plot you will generate below.

# %%
# load a saved marvin configuration you want to evaluate
model_name = 'Versuch3_32.h5'
marvin_reloaded = tf.keras.models.load_model(model_name)

# Let Marvin predict on the test set, so we have some data to evaluate his performance.
predictions = marvin_reloaded.predict([x_test])

# Remember that the prediction of Marvin is a probability distribution over all ten-digit classes
# We want him to assign the digit class with the highest probability to the sample.
predictions = np.argmax(predictions, axis=1)
#pd.DataFrame(predictions)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %%
# Plot for the intuitive approach

numbers_to_display = 294
num_cells = math.ceil(math.sqrt(numbers_to_display))
plt.figure(figsize=(15, 15))

for plot_index in range(numbers_to_display):    
    predicted_label = predictions[plot_index]
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    color_map = 'Greens' if predicted_label == y_test[plot_index] else 'Reds'
    plt.subplot(num_cells, num_cells, plot_index + 1)
    plt.imshow(x_test_normalized[plot_index].reshape((28, 28)), cmap=color_map)
    plt.xlabel(predicted_label)

plt.subplots_adjust(hspace=1, wspace=0.5)
plt.show()

# %%
# Here is some space for you to write down your thoughts on the side quest questions and experiments

...
# Out:
# Ellipsis

# %% [markdown]
# ### The Empirical Number Crushing Approach
#
# Now that you intuitively answered the questions, let's do some data analysis on the results and see how much you were off and where you were right and picked up patterns in Marvin's capabilities.
#
# #### Hint:
# Usually, visualizations to building your intuition are most beneficial during your first training runs on problems you do not know what to expect from your neural network. In visualizations, you might also be able to pick up wrong label assignments (think somebody labeled all "8"s as "9"s), ambiguous or overlapping classes (think somebody labeled all "6"s and "9"s as the same class). These things do not usually happen in beautifully cleaned datasets such as MNIST. But I promise you, you will be surprised how messy these public datasets out there are. And further, I promise you that if you are building your own datasets, these bugs will be there too and want to be found.
#
# Now for the analytical approach, we will look at one of the most basic strategies, the [confusion matrix](https://en.wikipedia.org/wiki/Confusion_matrix) or error matrix. This table shows the actual class of the sample (horizontal), plotted over which class it was predicted (vertical). To make things clearer, numbers in the diagonal are true positives, meaning Marvin predicted them correctly.
#
#
# <img src="graphics/arsenicBeans.svg" width="800"><br>

# %%
confusion_matrix = tf.math.confusion_matrix(y_test, predictions)

f, ax = plt.subplots(figsize=(9, 7))
sn.heatmap(
    confusion_matrix,
    annot=True,
    linewidths=.7,
    fmt="d",
    square=True,
    ax=ax,
    cmap="viridis",
)
plt.show()

# %%
# Here is some space for you to write down your thoughts on the side quest questions and experiments

...
# Out:
# Ellipsis

# %% [markdown]
# ### Time to say Goodbye
# Well, actually not quite yet. Now, you are capable of training neural networks, you learned about the fundamentals, and you also can evaluate your model's performance professionally. Next, I want to point out some things you can look into along your path to become a machine learning engineer or deep learning researcher.
#
# 1. Get a Stackoverflow account (https://stackoverflow.com/)
# 2. Get a GitHub account (https://github.com/)
# 3. Star this repo (https://github.com/schutera/DeepDive)
#
#
# #### In this notebook
# You can definitely come back to this notebook again and again. Play with the hyperparameters, try to follow through the notebook with other datasets. There are quite a few [directly supported](https://www.tensorflow.org/datasets/catalog/overview) by tensorflow, so they can easily plug into this notebook. Or try to load a dataset from your directory and write your own data pipeline.
#
# Come back and try working with other layers, such as Dropout or Batchnorm. Get to know regularization strategies, such as augmentation, and try to implement them here as well. Think of this notebook as your bridgehead to the world of deep learning. This is the place to break things and try stuff.
#
# #### Literature
# Reading helps to get to know new approaches, different ideas, and dive deeper and build up your knowledge. I recommend the following books to start with. From there, start to go with the actual papers.
#
# [To start with](http://www.deeplearningbook.org/) Deep Learning Book - Ian Goodfellow and Yoshua Bengio and Aaron Courville
# Abstract: The Deep Learning textbook is a resource intended to help students and practitioners enter the field of machine learning in general and deep learning in particular. The online version of the book is now complete and will remain available online for free.
#
# [Coffee Table Solutions](https://www.amazon.de/dp/B09QRGWWZP) The beginner handbook to Applied Deep Learning
# Abstract: The neural network was well into training for 42 hours. It all looked good - the gradients were flowing, the weights were updating, and the loss was decreasing. But then came the predictions for validation - all zeroes, no pattern recognized. What did I do wrong? — I asked my computer, who didn't answer. I noticed the dull feeling of despair and hopelessness rise inside my chest. After some more debugging and wasting more of the precious working hours, I would usually rededicate myself to the books, tutorials, and courses I knew so well by then. Somewhere had to be a hint to what I was missing - there was not. To give me a boost and to stay well caffeinated, I would usually go and grab a coffee in the coffee kitchen. Standing there at the coffee table with other students, researchers, developers, and practitioners, I would soon find myself indulging in the soft, warm feeling of getting this issue off my chest. And this is where the magic happened. Either someone already had a similar issue and knew how to fix it. Someone had an idea of narrowing down what the issue's root actually is about. Someone realized there was a conceptional problem in the data set or the model. Most of the time, what was shared at the coffee table were vague hints, interpretations and ideas, heuristics, best practices, experiences from applying deep learning in research and development. Over time we realized that some pitfalls, issues, and knowledge gaps were reoccurring in deep learning novices and were regularly brought to the coffee table while these students developed into deep learning engineers. Shortly after, we were taking notes. Throughout many sessions at the coffee table and hours of debugging, training, and evaluating deep learning approaches, researching and applying state-of-the-art concepts, we polished and enriched these notes with the great ideas that have been around and extensive references for further reading, based on our own experience. The result is this book. We hope it will be of use to you, too.
#
# [To understand the fundamentals](http://users.isr.ist.utl.pt/~wurmd/Livros/school/Bishop%20-%20Pattern%20Recognition%20And%20Machine%20Learning%20-%20Springer%20%202006.pdf) Pattern Recognition and Machine Learning - Bishop Abstract: This new textbook reﬂects these recent developments while providing a comprehensive introduction to the ﬁelds of pattern recognition and machine learning. It is aimed at advanced undergraduates or ﬁrst year Ph.D. students and researchers and practitioners and assumes no previous knowledge of pattern recognition or machine learning concepts.
#
# [From theory to practice and back](https://www.ksp.kit.edu/site/books/m/10.5445/KSP/1000008476/)
# Data Mining in der Medizin und Medizintechnik - Ralf Mikut Zusammenfassung: Dieses Buch systematisiert Ziele, Einsatzszenarien, Vorgehensweisen, Methoden und Anwendungsfelder für eine automatisierte Datenanalyse in der Medizin und Medizintechnik. Es wendet sich hauptsächlich an Doktoranden, Diplom- und Masterstudenten der Ingenieurwissenschaften und Informatik. Im Mittelpunkt steht dabei das Spannungsfeld zwischen medizinischen Anwendern und ihren Zielstellungen sowie den Potenzialen vorhandener Data-Mining-Verfahren.
#
# [To get practice](https://www.coursera.org/courses?query=andrew%20ng) Deep Learning and Machine Learning Courses on Coursera - Andrew Ng Abstract: In these courses, you will learn the foundations of Deep Learning, understand how to build neural networks, and learn how to lead successful machine learning projects. You will learn about Convolutional networks, RNNs, LSTM, Adam, Dropout, BatchNorm, Xavier/He initialization, and more. You will work on case studies from healthcare, autonomous driving, sign language reading, music generation, and natural language processing. You will master not only the theory but also see how it is applied in industry. You will practice all these ideas in Python and in TensorFlow, which we will teach.
# Link:
#
# [From beginning to mastery](http://cs231n.stanford.edu/) CS231n: Convolutional Neural Networks for Visual Recognition - Andrej Karpathy Abstract: Computer Vision has become ubiquitous in our society, with applications in search, image understanding, apps, mapping, medicine, drones, and self-driving cars. Core to many of these applications is a visual recognition task such as image classification, localization, and detection. Recent developments in neural networks (aka “deep learning”) have significantly advanced the performance of these state-of-the-art visual recognition systems. This course is a deep dive into details of the deep learning architectures focusing on learning end-to-end models for these tasks, particularly image classification. During the 10-week course, students will learn to implement, train, and debug their own neural networks and gain a detailed understanding of cutting-edge research in computer vision. The final assignment will involve training a multi-million parameter convolutional neural network and applying it on the largest image classification dataset (ImageNet). We will focus on teaching how to set up image recognition, the learning algorithms (e.g., backpropagation), practical engineering tricks for training and fine-tuning the networks, and guide the students through hands-on assignments and a final course project. Much of the background and materials of this course will be drawn from the ImageNet Challenge. There is also a YouTube [lecture](https://www.youtube.com/watch?v=NfnWJUyUJYU&list=PLkt2uSq6rBVctENoVBg1TpCC7OQi31AlC).
#
# [All things safety and validation](https://users.ece.cmu.edu/~koopman/lectures/index.html)
# Koopman lectures on why safety and validation is so hard in perception systems. You want to save a job within ADAS and AD in the automotive industry in the next 2 years. In my opinion this is your ticket.
#
#
# #### Mailing list
# There is so much more out there - different neural network architecture, different learning paradigms, not to mention endless real-world application possibilities.
# Every now and then, I'll share another part of this world. If you want to keep posted, write an e-mail to mark.schutera@kit.edu with the subject: "AppliedDeepLearningSchool Newsletter" - I promise there will be only a little spam.
#
# #### Someone deleted the internet, or a link broke in the notebook?
# You wanted to know more, click a link - and it was dead? That happens, as the internet and especially software is a living thing. In that case, I would be delighted if you'd let me know so that stuff gets fixed for the ones after you. You noticed a bug, a typo, an error, something? Send me an e-mail to mark.schutera@mailbox.org subject: "AppliedDeepLearningSchool Bug Hunt".
# Any other feedback is also highly appreciated.
#
# #### Can you use this code for a school or university project?
# Sure thing, go ahead. Just make sure to cite it appropriately. If you are unsure on how to do this, again, feel free to reach out. I can not wait to see you burning through school and university competitions with deep learning applications.
#
# #### You are looking for an intern position, or thesis, some freelancing on the side or some fun deep learning research project to join?
# Feel free to [connect and reach out](https://www.linkedin.com/in/schuteramark/).
#
#
# <img src="graphics/droplet.svg" width="650"><br>

# %% [markdown]
# 😇 Smiling Face with Halo

# %%
# Here is some space for you to write down your thoughts

...
# Out:
# Ellipsis
